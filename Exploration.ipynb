# %%
# !pip install pyarrow

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_parquet('data/ABAWS2324.parq')

# %%
data.head(10)
# Out:
#                          dose_grav01_hopper01_mattemp_r_value_act  \
# _time
# 2020-08-31 21:19:58.390                                       NaN
# 2020-08-31 21:19:58.900                                       NaN
# 2020-08-31 21:19:59.300                                       NaN
# 2020-08-31 21:19:59.420                                       NaN
# 2020-08-31 21:19:59.930                                       NaN
# 2020-08-31 21:20:00.450                                       NaN
# 2020-08-31 21:20:00.960                                       NaN
# 2020-08-31 21:20:01.300                                       NaN
# 2020-08-31 21:20:01.480                                       NaN
# 2020-08-31 21:20:01.990                                       NaN
#
#                          dose_grav01_hopper01_powerin_r_value_act  \
# _time
# 2020-08-31 21:19:58.390                                       NaN
# 2020-08-31 21:19:58.900                                       NaN
# ...
